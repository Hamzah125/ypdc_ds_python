# %%
#standard library 

from datetime import date,timedelta

# %%
print("harvest", date(2025,12,17), timedelta(125))
# Out:
# harvest 2025-12-17 125 days, 0:00:00

# %%
import pandas as pd

df = pd.DataFrame({"Crop":["wheat", "maiize"]},
                  {"yeild": [2500, 32000]})

print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 df = pd.DataFrame({"Crop":["wheat", "maiize"]},
#       4                   {"yeild": [2500, 32000]})
#       6 print(df.describe())
#
# File c:\Users\HP\Desktop\odyssey\venv\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...
