# %% [markdown]
# OPERATORS
# 1 Arithmetic
#
# 2 comparison
#
# 3 logical

# %%
# Arithmetic Operators in Python

# sum +
# subtraction -
# multiplication *
# division /
# floor division //
# modulus %

print(1+1)
print(3-1)
print(2*3)
# Out:
# 2
# 2
# 6

# %%
3-4
# Out:
# -1

# %%
4*4
# Out:
# 16

# %%
7/7
# Out:
# 1.0

# %%
4//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %% [markdown]
# Comparison Operator
# to ask a question like whether it is greater or whether smaller ,and return answer in true or false

# %%
# equal
57 == 57
56 == 57
# Out:
# False

# %%
# not equal to
64 != 54
# Out:
# True

# %%
# greater than

76 > 43
# Out:
# True

# %%
# less than

67 < 98
# Out:
# True

# %%
# greater than or equal 

54 >= 76
# Out:
# False

# %%
# less than or equal

76 >= 65
# Out:
# True

# %% [markdown]
# Logical Operator
# Multiple Questions to be adressed, if all conditions are met, then the result is True, otherwise False , if any of the conditions are not met, then the result is False.if met then reverse the result

# %%
# and operator

x=False
Y= False
x and Y
# Out:
# False

# %%
# or operator

x = True
Y = False
x or Y
# Out:
# True

# %%
# not operator

x = True
not x
# Out:
# False
