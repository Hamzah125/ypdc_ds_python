# %% [markdown]
# ## this is our first code

# %%
# syntax

print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# semantics

# %%
#single line comment

#1+1

# %% [markdown]
# ## it is my 2nd command

# %%
print("we are going to learn python")
# Out:
# we are going to learn python

# %%
print("h")
# Out:
# h

# %%
1+2
# Out:
# 3

# %%
# case sensitivity of python

Title = "ambassador"
title = "high comissioner"

# %%
print(Title)
# Out:
# ambassador

# %%
print(title)
# Out:
# high comissioner

# %%
# indentation

bps = 17

if bps < 17:
    print("you are a gazetted officer")

# %%
if bps > 17:
    print("you are not a gazetted officer")

# %%
# line continuation

sum = 2 + 4 +5 + 87 + 87 +65\
    +54 + 34 +29 + 23

# %%
# multiple statements in single line

a = 1 ; b = 4 ; c = 87
print(a);print(b);print(c)
# Out:
# 1
# 4
# 87
