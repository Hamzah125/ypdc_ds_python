# %% [markdown]
# functions is a block of code used to perform same tasks again and again and thus making the code reusable

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("saim"))
# Out:
# Hello, saim!
